# %% [markdown]
# ## NLP Modules and Tools

# %% [markdown]
# ### 1. English
# (참고: [https://theappsolutions.com/blog/development/nlp-tools/](https://theappsolutions.com/blog/development/nlp-tools/))
#
# - NLTK
# - Stanford Core NLP
# - Apache OpenNLP
# - SpaCy
# - Textacy
# - AllenNLP
# - Gensim
# - TextBlob
# - Intel NLP Architect

# %% [markdown]
# ### 1.1 NLTK (Natural Language ToolKit)
# an open-source software powered with Python NLP
#
# [https://www.nltk.org/](https://www.nltk.org/)
#
# NLTK provides users with a basic set of tools for text-related operations.
#
# NLTK includes:
# - Features: Text classification, Part-of-speech tagging, Entity extraction, Tokenization, Parsing, Stemming, Semantic reasoning
# - Text corpora and lexical resources: Penn Treebank Corpus, Open Multilingual Wordnet, Problem Report Corpus, Lin’s Dependency Thesaurus, ...

# %%
# !pip install nltk

# %%
import nltk
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# installing NLTK data
# nltk.download()  # 별도로 list에서 선택 ('all'을 선택하는 경우 모든 데이터를 다운로드)
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %%
nltk.download('gutenberg')  # 다운받을 자료를 선택, 명시해서 사용할 수도 있음
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# True

# %%
from nltk.corpus import gutenberg  # 다운받은 Gutenberg corpus를 import
gutenberg.raw()[:10000]
# Out:
# '[Emma by Jane Austen 1816]\n\nVOLUME I\n\nCHAPTER I\n\n\nEmma Woodhouse, handsome, clever, and rich, with a comfortable home\nand happy disposition, seemed to unite some of the best blessings\nof existence; and had lived nearly twenty-one years in the world\nwith very little to distress or vex her.\n\nShe was the youngest of the two daughters of a most affectionate,\nindulgent father; and had, in consequence of her sister\'s marriage,\nbeen mistress of his house from a very early period.  Her mother\nhad died too long ago for her to have more than an indistinct\nremembrance of her caresses; and her place had been supplied\nby an excellent woman as governess, who had fallen little short\nof a mother in affection.\n\nSixteen years had Miss Taylor been in Mr. Woodhouse\'s family,\nless as a governess than a friend, very fond of both daughters,\nbut particularly of Emma.  Between _them_ it was more the intimacy\nof sisters.  Even before Miss Taylor had ceased to hold the nominal\noffice
# ...

# %%
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
nltk.download('punkt')
gutenberg.sents('carroll-alice.txt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [['[', 'Alice', "'", 's', 'Adventures', 'in', 'Wonderland', 'by', 'Lewis', 'Carroll', '1865', ']'], ['CHAPTER', 'I', '.'], ...]

# %%
# tokenizing and tagging some text
sentence = "At eight o'clock on Thursday morning... Arthur didn't feel very good."
tokens = nltk.word_tokenize(sentence)
print(tokens)
# Out:
# ['At', 'eight', "o'clock", 'on', 'Thursday', 'morning', '...', 'Arthur', 'did', "n't", 'feel', 'very', 'good', '.']

# %%
nltk.download('averaged_perceptron_tagger')
tagged = nltk.pos_tag(tokens)
print(tagged)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [('At', 'IN'), ('eight', 'CD'), ("o'clock", 'NN'), ('on', 'IN'), ('Thursday', 'NNP'), ('morning', 'NN'), ('...', ':'), ('Arthur', 'NNP'), ('did', 'VBD'), ("n't", 'RB'), ('feel', 'VB'), ('very', 'RB'), ('good', 'JJ'), ('.', '.')]

# %%
# identifying named entities
nltk.download('maxent_ne_chunker')
nltk.download('words')

entities = nltk.chunk.ne_chunk(tagged)
print(entities)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# (S
#   At/IN
#   eight/CD
#   o'clock/NN
#   on/IN
#   Thursday/NNP
#   morning/NN
#   .../:
#   (PERSON Arthur/NNP)
#   did/VBD
#   n't/RB
#   feel/VB
#   very/RB
#   good/JJ
#   ./.)

# %%
# using other resources (lexicon, text corpora, ...)
nltk.download('treebank')

from nltk.corpus import treebank
print(treebank.fileids())
# Out:
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# ...

# %%
treebank.sents('wsj_0001.mrg')
# Out:
# [['Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov.', '29', '.'], ['Mr.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N.V.', ',', 'the', 'Dutch', 'publishing', 'group', '.']]

# %%
### CREATE VIRTUAL DISPLAY ###
# (NLTK tree 그림을 colab에서 보여주기 위한 부분)
# !apt-get install -y xvfb # Install X Virtual Frame Buffer
import os
os.system('Xvfb :1 -screen 0 1600x1200x16  &')    # create virtual display with size 1600x1200 and 16 bit color. Color can be changed to 24 or 8
os.environ['DISPLAY']=':1.0'    # tell X clients to use our virtual DISPLAY :1.0.

# %matplotlib inline
# !apt install ghostscript python3-tk
from IPython.display import display
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   xvfb
# 0 upgraded, 1 newly installed, 0 to remove and 39 not upgraded.
# Need to get 784 kB of archives.
# After this operation, 2,270 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.9 [784 kB]
# Fetched 784 kB in 1s (697 kB/s)
# Selecting previously unselected package xvfb.
# (Reading database ... 160772 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.9_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.9) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.9) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3-tk is already the newest version (3.6.9-1~18.04).
# ...

# %%
display(treebank.parsed_sents('wsj_0001.mrg')[0])
# Out:
# Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NNP', ['Pierre']), Tree('NNP', ['Vinken'])]), Tree(',', [',']), Tree('ADJP', [Tree('NP', [Tree('CD', ['61']), Tree('NNS', ['years'])]), Tree('JJ', ['old'])]), Tree(',', [','])]), Tree('VP', [Tree('MD', ['will']), Tree('VP', [Tree('VB', ['join']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['board'])]), Tree('PP-CLR', [Tree('IN', ['as']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['nonexecutive']), Tree('NN', ['director'])])]), Tree('NP-TMP', [Tree('NNP', ['Nov.']), Tree('CD', ['29'])])])]), Tree('.', ['.'])])

# %% [markdown]
# ### 1.2 Stanford Core NLP - Data Analysis, Sentiment Analysis, Conversational UI
#
# [https://stanfordnlp.github.io/CoreNLP/](https://stanfordnlp.github.io/CoreNLP/)
#
# a multi-purpose tool for text analysis
#
# based on Java
#
# *high scalability* - for processing large amounts of data and performing complex operations
#
# With its high scalability, Stanford CoreNLP is an excellent choice for:
#
# - information scraping from open sources (social media, user-generated reviews)
# - sentiment analysis (social media, customer support)
# - conversational interfaces(chatbots)
# - text processing, and generation(customer support, e-commerce)

# %% [markdown]
# demo visualization: [https://corenlp.run/](https://corenlp.run/)
#
# ![corenlp_demo.png](data:image/png;base64,...)

# %% [markdown]
# ### 1.3 Apache OpenNLP - Data Analysis and Sentiment Analysis
#
# [https://opennlp.apache.org/](https://opennlp.apache.org/)
#
# Java NLP libraries with Python decorators
#
# used by executing Java virtual machine
#
# a simple yet useful tool
#
# - Named Entity Recognition
# - Sentence Detection
# - POS tagging
# - Tokenization, Chunking, Parsing
# - Language Detection
# - Coreference Resolution

# %% [markdown]
# Chunker Example in Apache OpenNLP
#
# ![opennlp_demo.png](data:image/png;base64,...)
#
#
# image source: https://www.tutorialkart.com/opennlp/chunker-example-in-apache-opennlp/

# %% [markdown]
# ### 1.4 SpaCy - Data Extraction, Data Analysis, Sentiment Analysis, Text Summarization
#
# [https://spacy.io/](https://spacy.io/)
#
# a Python Library
#
# SpaCy provides users with a smoother, faster, and efficient experience (than NLTK).
#
# - Syntactic Analysis
# - Named Entity Recognition
# - Word Vector Usage: word2vec, doc2vec

# %%
# !pip install spacy

# %%
# !python -m spacy download en_core_web_sm
# !python -m spacy link en_core_web_sm en_default
# Out:
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
import spacy

# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_sm")

# %%
text = ("When Sebastian Thrun started working on self-driving cars at "
        "Google in 2007, few people outside of the company took him "
        "seriously. “I can tell you very senior CEOs of major American "
        "car companies would shake my hand and turn away because I wasn’t "
        "worth talking to,” said Thrun, in an interview with Recode earlier "
        "this week.")

# %%
# Simple tokenization

tokens = list(nlp.tokenizer(text))
print(tokens)
# Out:
# [When, Sebastian, Thrun, started, working, on, self, -, driving, cars, at, Google, in, 2007, ,, few, people, outside, of, the, company, took, him, seriously, ., “, I, can, tell, you, very, senior, CEOs, of, major, American, car, companies, would, shake, my, hand, and, turn, away, because, I, was, n’t, worth, talking, to, ,, ”, said, Thrun, ,, in, an, interview, with, Recode, earlier, this, week, .]

# %%
# Process whole documents

doc = nlp(text)

print(doc)
# Out:
# When Sebastian Thrun started working on self-driving cars at Google in 2007, few people outside of the company took him seriously. “I can tell you very senior CEOs of major American car companies would shake my hand and turn away because I wasn’t worth talking to,” said Thrun, in an interview with Recode earlier this week.

# %%
for token in doc:
  print(token)
# Out:
# When
# Sebastian
# Thrun
# started
# working
# on
# self
# -
# driving
# cars
# at
# Google
# in
# 2007
# ,
# few
# people
# outside
# of
# the
# company
# took
# him
# seriously
# .
# “
# I
# can
# tell
# you
# very
# senior
# CEOs
# of
# major
# American
# car
# companies
# would
# shake
# my
# hand
# and
# turn
# away
# because
# I
# was
# n’t
# worth
# talking
# to
# ,
# ”
# said
# Thrun
# ,
# in
# an
# interview
# with
# Recode
# earlier
# this
# week
# .

# %%
# obtaining lemma and part-of-speech of each token in the text

for token in doc:
  print(token.lemma_, token.pos_)
# Out:
# when ADV
# Sebastian PROPN
# Thrun PROPN
# start VERB
# work VERB
# on ADP
# self NOUN
# - PUNCT
# drive VERB
# car NOUN
# at ADP
# Google PROPN
# in ADP
# 2007 NUM
# , PUNCT
# few ADJ
# people NOUN
# outside ADV
# of ADP
# the DET
# company NOUN
# take VERB
# -PRON- PRON
# seriously ADV
# . PUNCT
# " PUNCT
# -PRON- PRON
# can VERB
# tell VERB
# -PRON- PRON
# very ADV
# senior ADJ
# ceo NOUN
# of ADP
# major ADJ
# american ADJ
# car NOUN
# company NOUN
# would VERB
# shake VERB
# -PRON- DET
# hand NOUN
# and CCONJ
# turn VERB
# away ADV
# because SCONJ
# -PRON- PRON
# be AUX
# not PART
# worth ADJ
# talk VERB
# to ADP
# , PUNCT
# " PUNCT
# say VERB
# Thrun PROPN
# , PUNCT
# in ADP
# an DET
# interview NOUN
# with ADP
# Recode PROPN
# earlier ADV
# this DET
# week NOUN
# . PUNCT

# %%
# obtaining verbs in the text

verbs = [token.lemma_ for token in doc if token.pos_ == "VERB"]

print(verbs)
# Out:
# ['start', 'work', 'drive', 'take', 'can', 'tell', 'would', 'shake', 'turn', 'talk', 'say']

# %%
# obtaining noun chunks
chunks = list(doc.noun_chunks)
print(chunks)
# Out:
# [Sebastian Thrun, self-driving cars, Google, few people, the company, him, I, you, very senior CEOs, major American car companies, my hand, I, Thrun, an interview, Recode]

# %%
# Find named entities, phrases and concepts

for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Sebastian NORP
# Google ORG
# 2007 DATE
# American NORP
# Recode ORG
# earlier this week DATE

# %% [markdown]
# ### +++ Textacy
#
# https://spacy.io/universe/project/textacy
#
# a Python Library
#
# built on the SpaCy library
#
# - tokenization, part-of-speech tagging, dependency parsing, etc.

# %% [markdown]
# ### 1.5 Others
#
# #### AllenNLP (https://allennlp.org/)
# - 데이터 전처리에 SpaCy 이용, 이후 단계 제공
# - Reading Comprehension, Visual Question Answering, Textual Entailment, Sentiment Analysis, ...
#
# #### TextBlob Library (https://textblob.readthedocs.io/en/dev/)
# - conversational interfaces
# - Sentiment Analysis, Machine Translation, Event Extraction, Intent Analysis, ...
#
# #### Intel NLP Architect (https://intellabs.github.io/nlp-architect/)
# - Machine Learning Comprehension (stylistic properties of texts), Term Set Expansion(TSE), ...
# - Application: text generation and summarization, aspect-based sentiment analysis, conversational interfaces such as chatbots, ...

# %% [markdown]
# #### Gensim (https://radimrehurek.com/gensim/)
# - an open-source NLP library designed for document exploration and topic modeling
# - Data analysis, Semantic search applications, Text generation applications (chatbot, service customization, text summarization, etc.), ...

# %%
# !pip install gensim

# %%
import gensim.downloader
# print(list(gensim.downloader.info()['models'].keys())) # Show all available models in gensim-data
w2v = gensim.downloader.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
w2v.most_similar('apple')
# Out:
# [('apples', 0.7203598022460938),
#  ('pear', 0.6450696587562561),
#  ('fruit', 0.6410146355628967),
#  ('berry', 0.6302294731140137),
#  ('pears', 0.6133961081504822),
#  ('strawberry', 0.6058261394500732),
#  ('peach', 0.6025873422622681),
#  ('potato', 0.596093475818634),
#  ('grape', 0.5935864448547363),
#  ('blueberry', 0.5866668224334717)]

# %% [markdown]
# ## 2. Korean
#
# (참고: https://github.com/datanada/Awesome-Korean-NLP)
#
# 공개된 한국어 리소스:
#
# - 형태소 분석기, 개체명 인식기, 맞춤법 검사기, 구문 분석기, 감정 분석기, 번역기, ...
# - 데이터셋
# - 언어 모델
# - 기타 어휘 사전 등

# %% [markdown]
# ### 2.1 KoNLPy
#
# https://konlpy.org/ko/v0.4.4/
#
# 한국어 정보처리를 위한 파이썬 패키지
#
# 다양한 형태소 분석기와 데이터, 사전 등을 파이썬 라이브러리 형태로 제공
# - 형태소 분석기: Kkma, Komoran, Hannanum, Twitter, Mecab
# - 말뭉치: kolaw (한국 법률 말뭉치), kobill (대한민국 국회 의안 말뭉치)
# - 사전: 말뭉치를 이용해 구성, 형태소 분석기에 사용됨
#
# (Hannanum 시스템 사전 - KAIST 말뭉치를 이용해 구성)
#
# (Kkma, Mecab 시스템 사전 - Sejong 말뭉치를 이용해 구성)

# %%
# install koNLPy
# !pip install konlpy
# Out:
# ...
#      |████████████████████████████████| 19.4MB 53.7MB/s
# ...
#      |████████████████████████████████| 450kB 41.1MB/s
# ...
#      |████████████████████████████████| 92kB 8.9MB/s
# ...
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
from konlpy.tag import Kkma
kkma = Kkma()
print(kkma.morphs('이것은 샘플 문장입니다.'))
print(kkma.nouns('이것도 샘플 문장입니다.'))
print(kkma.pos('이런 문장도 처리 가능합니다ㅋㅋ'))
print(kkma.sentences('이런 경우도 처리됩니다. 문장 분리!'))
# Out:
# ['이것', '은', '샘플', '문장', '이', 'ㅂ니다', '.']
# ['이것', '샘플', '문장']
# [('이런', 'MDT'), ('문장도', 'NNG'), ('처리', 'NNG'), ('가능', 'NNG'), ('하', 'XSV'), ('ㅂ니다', 'EFN'), ('ㅋㅋ', 'EMO')]
# ['이런 경우도 처리됩니다.', '문장 분리!']

# %%
from konlpy.tag import Okt
okt = Okt()
okt.pos('이런것도되지용ㅎㅎ')
# Out:
# [('이런', 'Modifier'),
#  ('것', 'Noun'),
#  ('도', 'Josa'),
#  ('되지용', 'Verb'),
#  ('ㅎㅎ', 'KoreanParticle')]

# %%
# install Mecab (optional) # after restarting runtime
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# !bash Mecab-ko-for-Google-Colab/install_mecab-ko_on_colab190912.sh
# Out:
# fatal: destination path 'Mecab-ko-for-Google-Colab' already exists and is not an empty directory.
# Installing konlpy.....
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2021-06-09 06:41:27--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::22c3:9b0a, 2406:da00:ff00::6b17:d1f5, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?Signature=K4PnrMgSr8zeBwu0uFOZFcPI9Dc%3D&Expires=1623222180&AWSAccessKeyId=AKIA6KOSE3BNJRRFUUX6&versionId=null&response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None [following]
# ...

# %%
# MeCab installation needed
from konlpy.tag import Mecab
mecab = Mecab()
print(mecab.pos(u'Mecab 설치는 어렵지만 속도가 빨라요!'))
# Out:
# [('Mecab', 'SL'), ('설치', 'VV'), ('는', 'ETM'), ('어렵', 'VA'), ('지만', 'EC'), ('속도', 'NNG'), ('가', 'JKS'), ('빨라요', 'VA+EF'), ('!', 'SF')]

# %%
# Corpus example
from konlpy.corpus import kolaw
c = kolaw.open('constitution.txt').read()
print(c[:100])

from konlpy.tag import Kkma
kkma = Kkma()
print(kkma.morphs(c[:1000]))
# Out:
# 대한민국헌법
#
# 유구한 역사와 전통에 빛나는 우리 대한국민은 3·1운동으로 건립된 대한민국임시정부의 법통과 불의에 항거한 4·19민주이념을 계승하고, 조국의 민주개혁과 평화적 통일의
# ...

# %% [markdown]
# ### 2.2 KoNLTK (Korean Natural Language ToolKit) - KoNLP
#
# http://konltk.org/en/latest/index.html
#
# python 언어를 이용하여 한글 관련 언어처리 작업을 하기 위한 플랫폼
#
# 형태소 분석, 품사 태깅, 구문 분석, 자동 띄어쓰기 등 한글 텍스트 처리, 언어처리 관련 라이브러리들에 대한 사용자 인터페이스 제공

# %%
# restart runtime
# !pip install wheel
# !pip install konlp

# %%
from konlp.kma.klt2000 import klt2000
k = klt2000()
simple_txt = "안녕하세요. 이것은 샘플 문장입니다."
print(k.pos(simple_txt))
print(k.morphs(simple_txt))
print(k.nouns(simple_txt))
# Out:
# ['안녕/N', '이것/K', '샘플/N', '문장/N']
# ['안녕', '이것', '샘플', '문장']
# ['안녕', '이것', '샘플', '문장']

# %% [markdown]
# ### 2.3 soynlp
#
# https://github.com/lovit/soynlp
#
# 한국어 분석을 위한 pure python code
#
# Word extractor, tokenizer, part-of-speech tagger, vectorizer 등 제공

# %%
# !pip install soynlp
# Out:
# ...
#      |████████████████████████████████| 419kB 9.0MB/s
# ...

# %%
# noun extractor 

from soynlp.utils import DoublespaceLineCorpus
from soynlp.noun import LRNounExtractor_v2

# !wget https://raw.githubusercontent.com/lovit/soynlp/master/data/91031_norm.txt
corpus_path = '91031_norm.txt'

print(open(corpus_path, 'r').read()[:200])
# Out:
# --2021-06-09 06:48:20--  https://raw.githubusercontent.com/lovit/soynlp/master/data/91031_norm.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1841455 (1.8M) [text/plain]
# Saving to: ‘91031_norm.txt.3’
#
# 91031_norm.txt.3    100%[===================>]   1.76M  --.-KB/s    in 0.06s
#
# 2021-06-09 06:48:20 (31.1 MB/s) - ‘91031_norm.txt.3’ saved [1841455/1841455]
#
# 재밌었다 그치만 지루한 부분도 있어서 9점	9
# 허술해서 안타까운 영화	4
# 황금달로 가는 신세계 무슨 다방이나 술집이름 같다만 골드문 한번 가볼 만한 신세계 무간도보다 참신하게 라는 목표는 달성하지 못했을지라도 한번 볼만한 가치는 충분히 있다 그대 호주머니에 극장 갈 돈이 있다면 아니면 케이블에서 해줄때까지 기다리셈	7
# 기대되네요ㅎ	10
# 시사회봤는데 범죄와의

# %%
sents = DoublespaceLineCorpus(corpus_path, iter_sent=True)

noun_extractor = LRNounExtractor_v2(verbose=True)
nouns = noun_extractor.train_extract(sents)
# Out:
# [Noun Extractor] use default predictors
# [Noun Extractor] num features: pos=3929, neg=2321, common=107
# [Noun Extractor] counting eojeols
# [EojeolCounter] n eojeol = 47478 from 19902 sents. mem=0.349 Gb
# [Noun Extractor] complete eojeol counter -> lr graph
# [Noun Extractor] has been trained. #eojeols=180610, mem=0.359 Gb
# [Noun Extractor] batch prediction was completed for 14382 words
# [Noun Extractor] checked compounds. discovered 4613 compounds
# [Noun Extractor] postprocessing detaching_features : 7835 -> 6607
# [Noun Extractor] postprocessing ignore_features : 6607 -> 6511
# [Noun Extractor] postprocessing ignore_NJ : 6511 -> 6452
# [Noun Extractor] 6452 nouns (4613 compounds) with min frequency=1
# [Noun Extractor] flushing was done. mem=0.381 Gb
# [Noun Extractor] 60.70 % eojeols are covered

# %%
print(list(sents)[:10])
# Out:
# ['재밌었다 그치만 지루한 부분도 있어서 9점\t9', '허술해서 안타까운 영화\t4', '황금달로 가는 신세계 무슨 다방이나 술집이름 같다만 골드문 한번 가볼 만한 신세계 무간도보다 참신하게 라는 목표는 달성하지 못했을지라도 한번 볼만한 가치는 충분히 있다 그대 호주머니에 극장 갈 돈이 있다면 아니면 케이블에서 해줄때까지 기다리셈\t7', '기대되네요ㅎ\t10', '시사회봤는데 범죄와의전쟁보다더재밌어요ㅎㅎㅎ 스토리장난아니고 배우들 연기도좋습니다 많이잔인해서 몇번 눈찔끔 감았지만 그래도 짱짱 완전 추천합니다\t10', 'ㅇㅇㅇㅇㅇㅇㅇㅇㅇ\t10', '화려한 배우들의 명품 연기가 기대대는 작품 인것 같습니다 정말 궁금하고 진정한 배우들의 연기 보고 싶습니다\t9', '현재까지 느와르 장르를 이렇게 섬세하고 뛰어나게 그린 작품이 없는듯 시사회 통해서 봤지만 분위기 탓이 아니라 객관적으로 너무 훌륭한 작품 황정민 연기 인생에서 절정을 본듯 진짜최고 완전 팬됨 난 심지어 여자인데 너무재밋게봄 최고\t9', '스토리 흥미있고 재미있다\t10', '완전기대만빵\t10']

# %%
print(nouns)
# Out:
# {'황정민연기진짜잘': NounScore(frequency=4, score=1.0), '말이필요없는영화': NounScore(frequency=6, score=1.0), '돈이안아까운영화': NounScore(frequency=2, score=1.0), '간만에재밌는영화': NounScore(frequency=1, score=0.5), 'departed': NounScore(frequency=3, score=1.0), '청소년관람불가': NounScore(frequency=1, score=1.0), '아깝지않은영화': NounScore(frequency=2, score=1.0), '무슨말이더필요': NounScore(frequency=2, score=1.0), '연기력들이ㄷㄷ': NounScore(frequency=1, score=0.5), '배우들의연기력': NounScore(frequency=2, score=0.4), '황정민연기때문': NounScore(frequency=2, score=1.0), '엘레베이터장면': NounScore(frequency=1, score=0.5), '캐릭터하나하나': NounScore(frequency=2, score=1.0), '배우들하나하나': NounScore(frequency=2, score=1.0), '또보고싶은영화': NounScore(frequency=13, score=0.8666666666666667), '무간도리메이크': NounScore(frequency=2, score=0.5), '달콤한인생이후': NounScore(frequency=3, score=1.0), '또보고싶을정도': NounScore(frequency=2, score=1.0), '박성웅이란배우': NounScore(frequency=2, score=1.0), '이스턴프라미스': NounScore(frequency=6, score=1.0), '한국느와르영화': NounScore(frequency=6, score=1.0), '황정민과이정재':
# ...

# %%
# Tokenizer
# WordExtractor가 학습한 단어의 점수를 이용해 문장의 단어 경계 분리

from soynlp.tokenizer import LTokenizer

scores = {'데이':0.5, '데이터':0.5, '데이터마이닝':0.5, '공부':0.5, '공부중':0.45}
tokenizer = LTokenizer(scores=scores)
sent = '데이터마이닝을 공부한다'

print(tokenizer.tokenize(sent, flatten=False))
print(tokenizer.tokenize(sent))
# Out:
# [('데이터마이닝', '을'), ('공부', '한다')]
# ['데이터마이닝', '을', '공부', '한다']

# %% [markdown]
# 그 외 기능들
# - Part of Speech Tagger: 사전 기반 품사 판별기
# - Vectorizer: 토크나이저를 학습하거나, 혹은 학습된 토크나이저를 이용하여 문서를 sparse matrix로 변환
# - Normalizer: 대화 데이터, 댓글 데이터에 등장하는 반복되는 이모티콘의 정리 및 한글, 혹은 텍스트만 남기기 위한 함수를 제공
#
# - Point-wise Mutual Information (PMI): 연관어 분석을 위한 co-occurrence matrix 계산과 이를 이용한 Point-wise Mutual Information (PMI) 계산을 위한 함수를 제공
#
# - soyspacing: 분석하려는 데이터를 기반으로 띄어쓰기 엔진을 학습하고, 이를 이용하여 띄어쓰기 오류를 교정
# - soykeyword: 키워드 추출기
#
# ...

# %% [markdown]
# ### 2.4 Others
# - Hangulpy: 자동 조사/접미사 첨부, 자모 분해 및 결합 (https://github.com/rhobot/Hangulpy)
# - kroman: hangul romanization tool (https://github.com/zhangkaiyulw/kroman)
# - Hangulize: 외래어 자동 한글 변환 모듈 (https://github.com/sublee/hangulize)

# %%
# Hangulize example
# !pip install hangulize
from hangulize import hangulize
print(hangulize(u'Ἡρακλῆς', 'grc'))
print(hangulize(u"Giro d'Italia", 'ita'))

# Go로 재구현되어 Python은 더 업데이트 되지 않음
# Out:
# ...
#      |████████████████████████████████| 143kB 8.1MB/s
# ...
#   Created wheel for hangulize: filename=hangulize-0.0.9-cp37-none-any.whl size=171341 sha256=66733fd6e7ca19e152eba9b182771d4d39322d2689bb586d44d52912a1d8315d
#   Stored in directory: /root/.cache/pip/wheels/b7/89/2b/f6b06e5f7738043c3dfdb0faec0a6d3bfa20d145c88f8abf90
# Successfully built hangulize
# ...
# 헤라클레스
# 지로 디탈리아

# %% [markdown]
# - hanja: 한자/한글 변환기 (https://pypi.org/project/hanja/)

# %%
# hanja example
# !pip install hanja
import hanja
from hanja import hangul
# Out:
# ...
#      |████████████████████████████████| 122kB 9.4MB/s
# ...
#      |████████████████████████████████| 266kB 13.5MB/s
# ...
#   Created wheel for hanja: filename=hanja-0.13.3-cp37-none-any.whl size=128426 sha256=270e32d6db098ae8ee43a4c9270028cc735cec56c63d72caee0c5d2c0f9efadc
#   Stored in directory: /root/.cache/pip/wheels/45/fc/c9/b7e7cb5c86935a1a99e2ad07f763728f8f17560e7b815a4b27
# ...
#   Created wheel for pyyaml: filename=PyYAML-5.1.2-cp37-cp37m-linux_x86_64.whl size=44117 sha256=0b5c9c9a850d538c724230d44ba09f25cb50ca16036f49287e4fd04dc1b86221
#   Stored in directory: /root/.cache/pip/wheels/d9/45/dd/65f0b38450c47cf7e5312883deb97d065e030c5cca0a365030
# Successfully built hanja pyyaml
# ...
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# 한글 초성, 중성, 종성 분리
print(hangul.separate('가'))
print(hangul.separate('한'))
# Out:
# (0, 0, 0)
# (18, 0, 4)

# %%
# 초성, 중성, 종성을 조합하여 한 글자를 만듦
print(hangul.build(0, 0, 0))
print(hangul.build(18, 0, 4))
# Out:
# 가
# 한

# %%
# 주어진 글자가 한글/한자인지의 여부를 판별
print(hangul.is_hangul('각'))
print(hanja.is_hanja('韓'))
# Out:
# True
# True

# %%
# 문장 변환
print(hanja.translate('大韓民國은 民主共和國이다.', 'substitution'))
print(hanja.translate('大韓民國은 民主共和國이다.', 'combination-text'))
# Out:
# 대한민국은 민주공화국이다.
# 大韓民國(대한민국)은 民主共和國(민주공화국)이다.
